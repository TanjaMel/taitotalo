# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %%
df = sns.load_dataset('titanic')
df.head(15)
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
df.shape
# Out:
# (891, 15)

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df.isna()
# Out:
#      survived  pclass    sex    age  sibsp  parch   fare  embarked  class  \
# 0       False   False  False  False  False  False  False     False  False
# 1       False   False  False  False  False  False  False     False  False
# 2       False   False  False  False  False  False  False     False  False
# 3       False   False  False  False  False  False  False     False  False
# 4       False   False  False  False  False  False  False     False  False
# ..        ...     ...    ...    ...    ...    ...    ...       ...    ...
# 886     False   False  False  False  False  False  False     False  False
# 887     False   False  False  False  False  False  False     False  False
# 888     False   False  False   True  False  False  False     False  False
# 889     False   False  False  False  False  False  False     False  False
# 890     False   False  False  False  False  False  False     False  False
#
#        who  adult_male   deck  embark_town  alive  alone
# ...

# %%
#df.dropna()

# %%
df.duplicated()
df = df.drop_duplicates(ignore_index=True)
df.shape
# Out:
# (784, 15)

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  784.000000  784.000000  678.000000  784.000000  784.000000  784.000000
# mean     0.411990    2.243622   29.869351    0.522959    0.415816   34.711740
# std      0.492507    0.855056   14.759076    0.986231    0.836922   52.160151
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    1.000000   20.000000    0.000000    0.000000    8.050000
# 50%      0.000000    3.000000   28.250000    0.000000    0.000000   15.900000
# 75%      1.000000    3.000000   39.000000    1.000000    1.000000   34.109350
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df.hist(figsize=(10,7), bins=20)
plt.show()

# %%
sns.boxplot(data=df, x='fare')
plt.show()

# %%
plt.figure(figsize=(7,5))
sns.boxplot(data=df, x='pclass', y='fare', hue='survived')
plt.title("Matkalipun hinta ja matkustusluokka suhteessa selviytymiseen")
#plt.ylim(0,300)
plt.show()

# %%
np.where(df['fare']>500)
# Out:
# (array([243, 600, 652]),)

# %%
df.loc[[243,600,652]]
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked  class  \
# 243         1       1  female  35.0      0      0  512.3292        C  First
# 600         1       1    male  36.0      0      1  512.3292        C  First
# 652         1       1    male  35.0      0      0  512.3292        C  First
#
#        who  adult_male deck embark_town alive  alone
# 243  woman       False  NaN   Cherbourg   yes   True
# 600    man        True    B   Cherbourg   yes  False
# 652    man        True    B   Cherbourg   yes   True

# %%
largest_fare = df.loc[:,'fare'].nlargest(n=20)
largest_fare
# Out:
# 243    512.3292
# 600    512.3292
# 652    512.3292
# 27     263.0000
# 84     263.0000
# 317    263.0000
# 398    263.0000
# 291    262.3750
# 655    262.3750
# 112    247.5208
# 281    247.5208
# 349    227.5250
# 500    227.5250
# 619    227.5250
# 634    227.5250
# 471    221.7792
# 346    211.5000
# 610    211.3375
# 648    211.3375
# 688    211.3375
# Name: fare, dtype: float64

# %%
indeksit = df.loc[largest_fare.index]
indeksit
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked  class  \
# 243         1       1  female  35.0      0      0  512.3292        C  First
# 600         1       1    male  36.0      0      1  512.3292        C  First
# 652         1       1    male  35.0      0      0  512.3292        C  First
# 27          0       1    male  19.0      3      2  263.0000        S  First
# 84          1       1  female  23.0      3      2  263.0000        S  First
# 317         1       1  female  24.0      3      2  263.0000        S  First
# 398         0       1    male  64.0      1      4  263.0000        S  First
# 291         1       1  female  18.0      2      2  262.3750        C  First
# 655         1       1  female  21.0      2      2  262.3750        C  First
# 112         0       1    male  24.0      0      1  247.5208        C  First
# 281         1       1  female  50.0      0      1  247.5208        C  First
# ...

# %%
sns.barplot(data=df, x='pclass', y='survived', hue='who', palette='viridis')
plt.show()

# %%
df['fare_range'] = pd.qcut(df['fare'],4)
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0           0       3    male  22.0      1      0   7.2500        S  Third
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 2           1       3  female  26.0      0      0   7.9250        S  Third
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 4           0       3    male  35.0      0      0   8.0500        S  Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 779         0       3  female  39.0      0      5  29.1250        Q  Third
# 780         1       1  female  19.0      0      0  30.0000        S  First
# 781         0       3  female   NaN      1      2  23.4500        S  Third
# 782         1       1    male  26.0      0      0  30.0000        C  First
# 783         0       3    male  32.0      0      0   7.7500        Q  Third
#
# ...

# %%
sns.barplot(data=df, x='survived', y='fare_range')
# Out:
# <Axes: xlabel='survived', ylabel='fare_range'>

# %%
df2 = df.groupby(['sex', 'alive']).size().reset_index(name='number')
df2
# Out:
#       sex alive  number
# 0  female    no      76
# 1  female   yes     217
# 2    male    no     385
# 3    male   yes     106

# %%
sns.barplot(data=df2, x='sex', y='number', hue='alive')
# Out:
# <Axes: xlabel='sex', ylabel='number'>

# %%
df3 = df.drop(['sex', 'embarked', 'class', 'who', 'embark_town', 'deck', 'alive', 'fare_range'], axis=1)

# %%
corr_matrix = df3.corr()
corr_matrix
# Out:
#             survived    pclass       age     sibsp     parch      fare  \
# survived    1.000000 -0.332658 -0.086548 -0.036589  0.070307  0.246769
# pclass     -0.332658  1.000000 -0.369361  0.088014  0.040296 -0.549216
# age        -0.086548 -0.369361  1.000000 -0.315116 -0.195036  0.092707
# sibsp      -0.036589  0.088014 -0.315116  1.000000  0.381433  0.135147
# parch       0.070307  0.040296 -0.195036  0.381433  1.000000  0.191942
# fare        0.246769 -0.549216  0.092707  0.135147  0.191942  1.000000
# adult_male -0.528502  0.066816  0.296095 -0.274521 -0.347186 -0.165209
# alone      -0.176595  0.109545  0.210047 -0.609502 -0.571087 -0.246619
#
#             adult_male     alone
# survived     -0.528502 -0.176595
# pclass        0.066816  0.109545
# age           0.296095  0.210047
# sibsp        -0.274521 -0.609502
# parch        -0.347186 -0.571087
# fare         -0.165209 -0.246619
# adult_male    1.000000  0.387850
# alone         0.387850  1.000000

# %%
sns.heatmap(corr_matrix, vmin=-1.0, vmax=1.0, cmap='RdBu', annot=True)
# Out:
# <Axes: >
